# %%
import math

import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('test_calc.txt', sep=" ", header=None)
df.columns = ['x', 'y_0', 'y_1']

# %%
df
# Out:
#         x      y_0       y_1
# 0    0.00  2.00000  0.000000
# 1    0.02  1.98682 -0.674654
# 2    0.04  1.97326 -0.681697
# 3    0.06  1.95955 -0.690129
# 4    0.08  1.94567 -0.699011
# ..    ...      ...       ...
# 96   1.92  1.82892 -0.780198
# 97   1.94  1.81320 -0.793381
# 98   1.96  1.79723 -0.806243
# 99   1.98  1.78097 -0.821074
# 100  2.00  1.76443 -0.834270
#
# [101 rows x 3 columns]

# %%
sns.lineplot(df, x='x', y='y_0')
# Out:
# <Axes: xlabel='x', ylabel='y_0'>

# %%
sns.lineplot(df, x='x', y='y_1')
# Out:
# <Axes: xlabel='x', ylabel='y_1'>

# %%
sns.lineplot(df, x='y_1', y='y_0')
# Out:
# <Axes: xlabel='y_1', ylabel='y_0'>

# %%
df_bw = pd.read_csv('test_calc_backwards.txt', sep=" ", header=None)
df_bw.columns = ['x', 'y_0', 'y_1']

# %%
sns.lineplot(df_bw, x='x', y='y_0')
# Out:
# <Axes: xlabel='x', ylabel='y_0'>

# %%
sns.lineplot(df_bw, x='x', y='y_1')
# Out:
# <Axes: xlabel='x', ylabel='y_1'>

# %%
df_merged = pd.concat([df, df_bw], axis=0)

# %%
sns.lineplot(df_merged, x='x', y='y_0')
# Out:
# <Axes: xlabel='x', ylabel='y_0'>

# %%
sns.lineplot(df_merged, x='x', y='y_1')
# Out:
# <Axes: xlabel='x', ylabel='y_1'>
